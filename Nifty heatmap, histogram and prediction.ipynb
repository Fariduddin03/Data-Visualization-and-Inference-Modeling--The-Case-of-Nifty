# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %% [markdown]
# # Taking Dataset

# %%
data=pd.read_csv("C:\\Users\\saira\\Downloads\\niftydata20yrs.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    24 non-null     int64
#  1   Jan     24 non-null     float64
#  2   Feb     24 non-null     float64
#  3   Mar     24 non-null     float64
#  4   Apr     24 non-null     float64
#  5   May     24 non-null     float64
#  6   Jun     24 non-null     float64
#  7   Jul     24 non-null     float64
#  8   Aug     24 non-null     float64
#  9   Sep     24 non-null     float64
#  10  Oct     24 non-null     float64
#  11  Nov     24 non-null     float64
#  12  Dec     24 non-null     float64
#  13  Annual  24 non-null     float64
# dtypes: float64(13), int64(1)
# memory usage: 2.8 KB

# %%
data.isnull().sum()
# Out:
# Year      0
# Jan       0
# Feb       0
# Mar       0
# Apr       0
# May       0
# Jun       0
# Jul       0
# Aug       0
# Sep       0
# Oct       0
# Nov       0
# Dec       0
# Annual    0
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.isnull(),cmap='viridis')
plt.show()

# %%
data.describe()
# Out:
#               Year        Jan        Feb        Mar        Apr        May  \
# count    24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean   2011.500000  -0.281250  -0.298333  -0.287083   1.548750   0.900417
# std       7.071068   6.195129   4.425121   8.379307   5.838073   8.718744
# min    2000.000000 -16.310000  -8.260000 -23.250000  -7.980000 -17.400000
# 25%    2005.750000  -3.480000  -3.562500  -3.862500  -2.017500  -3.375000
# 50%    2011.500000  -0.695000   0.230000   0.070000   0.810000   1.215000
# 75%    2017.250000   4.477500   2.607500   6.682500   4.410000   4.235000
# max    2023.000000  12.430000   7.020000  10.750000  15.000000  28.070000
#
#              Jun        Jul        Aug        Sep        Oct        Nov  \
# count  24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean    1.175000   1.852500   1.368750   1.171667   0.889583   2.885417
# std     5.749983   5.252393   4.982137   6.855647   8.441458   5.869075
# ...

# %%
data2 = data.drop(columns=['Year','Annual'])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     24 non-null     float64
#  1   Feb     24 non-null     float64
#  2   Mar     24 non-null     float64
#  3   Apr     24 non-null     float64
#  4   May     24 non-null     float64
#  5   Jun     24 non-null     float64
#  6   Jul     24 non-null     float64
#  7   Aug     24 non-null     float64
#  8   Sep     24 non-null     float64
#  9   Oct     24 non-null     float64
#  10  Nov     24 non-null     float64
#  11  Dec     24 non-null     float64
# dtypes: float64(12)
# memory usage: 2.4 KB

# %% [markdown]
# # Heatmap

# %%
colors = ["#AA336A", "#FFB6C1", "#FAFAD2", "#90EE90", "#32CD32", "#006400"]  # Dark Pink, Light Pink, White, Light Green, Dark Green, Dark Green
cmap = sns.color_palette(colors, as_cmap=True)

plt.figure(figsize=(12, 8))
sns.heatmap(data2, cmap=cmap, annot=True, fmt=".2f", linewidths=.5)
plt.title('Monthly Returns (2000-2023)')
plt.xlabel('Months')
plt.ylabel('Years')
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(12, 10))
plt.bar(data['Year'], data['Jan'], color='skyblue', edgecolor='black', width=0.8)  
plt.title("Histogram of January returns", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Returns", fontsize=14)
plt.xticks(range(2000, 2024), rotation=45, ha='right', fontsize=12)
plt.yticks(range(-17, 16), fontsize=12)
plt.xlim(1999.5, 2023.5)
plt.ylim(-17, 16)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.plot(data['Year'], data['Jan'], color='skyblue', marker='o', linewidth=3) 
plt.title("Histogram plot curve of January returns", fontsize=16)
plt.xlabel("Years", fontsize=14)
plt.ylabel("Returns", fontsize=14)
plt.xticks(range(2000, 2024), rotation=45, ha='right', fontsize=12)
plt.yticks(range(-17, 16), fontsize=12)
plt.xlim(1999.5, 2023.5)
plt.ylim(-17, 16)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'data' and contains columns for each month
for column in data.columns[1:]:
    plt.figure(figsize=(12, 10))
    plt.plot(data['Year'], data[column], color='skyblue', marker='o', linewidth=3) 
    plt.title(f"Histogram plot curve of {column} returns", fontsize=16)
    plt.xlabel("Years", fontsize=14)
    plt.ylabel("Returns", fontsize=14)
    plt.xticks(range(2000, 2024), rotation=45, ha='right', fontsize=12)
    plt.yticks(fontsize=12)
    plt.xlim(1999.5, 2023.5)
    plt.show()

# %%
import matplotlib.pyplot as plt

for column in data.columns[1:]: 
    plt.figure(figsize=(12, 10))
    plt.bar(data['Year'], data[column], color='skyblue', edgecolor='black', width=0.8)  
    plt.title(f"Histogram of {column} returns", fontsize=16)
    plt.xlabel("Year", fontsize=14)
    plt.ylabel("Returns", fontsize=14)
    plt.xticks(range(2000, 2024), rotation=45, ha='right', fontsize=12)
    plt.xlim(1999.5, 2023.5)
    plt.show()

# %% [markdown]
# # histogram annual returns

# %%
plt.figure(figsize=(12, 10))
plt.bar(data['Year'], data['Annual'], color='skyblue', edgecolor='black', width=0.8)  
plt.title("Histogram of Annual returns", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Returns", fontsize=14)
plt.xticks(range(2000, 2024), rotation=45, ha='right', fontsize=12)
plt.xlim(1999.5, 2023.5)
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.plot(data['Year'], data['Annual'], color='skyblue', marker='o', linewidth=3) 
plt.title("Histogram of Annual returns", fontsize=16)
plt.xlabel("Years", fontsize=14)
plt.ylabel("Returns", fontsize=14)
plt.xticks(range(2000, 2024), rotation=45, ha='right', fontsize=12)
plt.show()

# %%
january_returns = data['Jan']

mean_return = np.mean(january_returns)
std_deviation = np.std(january_returns)

bins = [-np.inf, mean_return - 2 * std_deviation, mean_return - std_deviation, 
        mean_return + std_deviation, mean_return + 2 * std_deviation, np.inf]

bins = [bin_ for bin_ in bins if bin_ != np.inf and bin_ != -np.inf]

plt.figure(figsize=(10, 6))
plt.hist(january_returns, bins=bins, edgecolor='black')
plt.title('Histogram of January Returns for Nifty')
plt.xlabel('January Returns')
plt.ylabel('Frequency')
plt.xticks([bin_ for bin_ in bins if not np.isinf(bin_)])
plt.grid(True)
plt.show()

# %%
january_returns = data['Feb']

mean_return = np.mean(january_returns)
std_deviation = np.std(january_returns)

bins = [-np.inf, mean_return - 2 * std_deviation, mean_return - std_deviation, 
        mean_return + std_deviation, mean_return + 2 * std_deviation, np.inf]

bins = [bin_ for bin_ in bins if bin_ != np.inf and bin_ != -np.inf]

plt.figure(figsize=(10, 6))
plt.hist(january_returns, bins=bins, edgecolor='black')
plt.title('Histogram of January Returns for Nifty')
plt.xlabel('January Returns')
plt.ylabel('Frequency')
plt.xticks([bin_ for bin_ in bins if not np.isinf(bin_)])
plt.grid(True)
plt.show()

# %%
january_returns = data['Annual']

mean_return = np.mean(january_returns)
std_deviation = np.std(january_returns)

bins = [-np.inf, mean_return - 2 * std_deviation, mean_return - std_deviation, 
        mean_return + std_deviation, mean_return + 2 * std_deviation, np.inf]

bins = [bin_ for bin_ in bins if bin_ != np.inf and bin_ != -np.inf]

plt.figure(figsize=(10, 6))
plt.hist(january_returns, bins=bins, edgecolor='black')
plt.title('Histogram of January Returns for Nifty')
plt.xlabel('January Returns')
plt.ylabel('Frequency')
plt.xticks([bin_ for bin_ in bins if not np.isinf(bin_)])
plt.grid(True)
plt.show()

# %% [markdown]
# # ARIMA model

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

p, d, q = 24, 0, 24

num_steps = 10  

forecast_df = pd.DataFrame()

for column in data.columns:
    
    series = data[column]
    
    model = ARIMA(series, order=(p, d, q))
    model_fit = model.fit()
    
    forecast = model_fit.forecast(steps=num_steps)
    
    forecast_df[column] = forecast

print(forecast_df)
# Out:
# C:\Users\saira\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\saira\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\saira\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\saira\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import pacf 
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.arima.model import ARIMA

d = 0

num_steps = 10 

forecast_df = pd.DataFrame()

max_pacf_lag = 0
for column in data.columns[1:]:
  
    series = data[column]
    
   
    pacf_values = pacf(series, nlags=6)
    
  
    max_pacf_index = (np.abs(pacf_values[1:]) > 0.05).argmax() + 1
    if max_pacf_index > max_pacf_lag:
        max_pacf_lag = max_pacf_index


p = max_pacf_lag


max_acf_lag = 0
for column in data.columns[1:]:
    acf_values = acf(data[column], nlags=12)
    max_acf_index = (np.abs(acf_values[1:]) > 0.05).argmax() + 1
    if max_acf_index > max_acf_lag:
        max_acf_lag = max_acf_index

q = max_acf_lag


for column in data.columns[1:]:
   
    series = data[column]
    
   
    model = ARIMA(series, order=(p, d, q))
    model_fit = model.fit()
    
  
    forecast = model_fit.forecast(steps=num_steps)
    
    
    forecast_df[column] = forecast

print(forecast_df)
# Out:
# C:\Users\saira\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\saira\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\saira\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\saira\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ...
